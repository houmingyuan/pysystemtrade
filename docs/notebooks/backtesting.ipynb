# %% [markdown]
# ### 系统交易十五章中的例子系统。
#
# 配置在 systems/provided/futures_chapter15/futuresconfig.yaml

# %%
# 从 pysystemtrade 框架中导入期货交易系统模块
from systems.provided.futures_chapter15.basesystem import futures_system

# 初始化一个期货交易系统实例
system=futures_system()

# 获取玉米期货的名义持仓量
# 名义持仓量通常表示未经过风险调整的原始持仓规模
system.portfolio.get_notional_position("CORN")
# Out:
# 2025-03-31 19:17:15 DEBUG config {'type': 'config', 'stage': 'config'} Adding config defaults
# 2025-03-31 19:17:15 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-03-31 19:17:15 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-03-31 19:17:15 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating notional position for CORN
# 2025-03-31 19:17:15 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating instrument weights
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating raw instrument weights
# 2025-03-31 19:17:15 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-03-31 19:17:15 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-03-31 19:17:15 DEBUG base_system Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2025-03-31 19:17:15 DEBUG base_system Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2025-03-31 19:17:15 DEBUG base_system Following instruments marked as not trading []
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating subsystem position for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating volatility scalar for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating instrument value vol for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating instrument currency vol for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily volatility for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating combined forecast for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN carry
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for carry
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac16_64
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac16_64
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac32_128
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac32_128
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac64_256
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac64_256
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating forecast weights for CORN
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX carry
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for carry
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily volatility for EUROSTX
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP carry
# 2025-03-31 19:17:15 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for carry
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily volatility for MXP
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR carry
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for carry
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily volatility for SOFR
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 carry
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for carry
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily volatility for US10
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X carry
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for carry
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily volatility for V2X
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac16_64
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac16_64
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac16_64
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac16_64
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac16_64
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac16_64
# 2025-03-31 19:17:16 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac16_64
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac16_64
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac16_64
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac16_64
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac32_128
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac64_256
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Non-nested dict of forecast weights for CORN {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Using fixed FDM multiplier of 1.310 for CORN
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} No mapping applied for CORN
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating subsystem position for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating volatility scalar for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating instrument value vol for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating instrument currency vol for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating combined forecast for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating forecast weights for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:17 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Non-nested dict of forecast weights for EUROSTX {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Using fixed FDM multiplier of 1.310 for EUROSTX
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} No mapping applied for EUROSTX
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating subsystem position for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating volatility scalar for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating instrument value vol for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating instrument currency vol for MXP
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating combined forecast for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating forecast weights for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Non-nested dict of forecast weights for MXP {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Using fixed FDM multiplier of 1.310 for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} No mapping applied for MXP
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating subsystem position for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating volatility scalar for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating instrument value vol for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating instrument currency vol for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating combined forecast for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating forecast weights for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Non-nested dict of forecast weights for SOFR {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Using fixed FDM multiplier of 1.310 for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} No mapping applied for SOFR
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating subsystem position for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating volatility scalar for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating instrument value vol for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating instrument currency vol for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating combined forecast for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating forecast weights for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Non-nested dict of forecast weights for US10 {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Using fixed FDM multiplier of 1.310 for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} No mapping applied for US10
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating subsystem position for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating volatility scalar for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating instrument value vol for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating instrument currency vol for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating combined forecast for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating forecast weights for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Non-nested dict of forecast weights for V2X {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Using fixed FDM multiplier of 1.310 for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} No mapping applied for V2X
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Following instruments will have zero weight in optimisation of instrument weights as they have no positions (possibly too expensive?) []
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:18 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Using fixed diversification multiplier 1.890000
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} No risk overlay in config: won't apply risk scaling
# index
# 1972-10-18         NaN
# 1972-10-19         NaN
# 1972-10-20         NaN
# 1972-10-23         NaN
# 1972-10-24         NaN
#                 ...
# 2024-03-22   -9.363091
# 2024-03-25   -9.527996
# 2024-03-26   -8.926035
# 2024-03-27   -8.795127
# 2024-03-28   -6.394491
# Freq: B, Length: 13422, dtype: float64

# %% [markdown]
# ### 一个带有估算参数的回测系统

# %%
from systems.provided.futures_chapter15.estimatedsystem import futures_system
system=futures_system()
system.portfolio.get_notional_position("CORN")
# Out:
# 2025-03-31 19:17:18 DEBUG config {'type': 'config', 'stage': 'config'} Adding config defaults
# 2025-03-31 19:17:18 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-03-31 19:17:18 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-03-31 19:17:18 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating notional position for CORN
# 2025-03-31 19:17:18 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating instrument weights
# 2025-03-31 19:17:18 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-03-31 19:17:18 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-03-31 19:17:18 DEBUG base_system Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2025-03-31 19:17:18 DEBUG base_system Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2025-03-31 19:17:18 DEBUG base_system Following instruments marked as not trading []
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating subsystem position for CORN
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating volatility scalar for CORN
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating instrument value vol for CORN
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating instrument currency vol for CORN
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily volatility for CORN
# 2025-03-31 19:17:18 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating combined forecast for CORN
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN carry
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for carry
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Getting cross sectional forecasts for scalar calculation for carry over CORN, EUROSTX, MXP, SOFR, US10, V2X
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for carry
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily volatility for EUROSTX
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for carry
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily volatility for MXP
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for carry
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily volatility for SOFR
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for carry
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily volatility for US10
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for carry
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily volatility for V2X
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac16_64
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac16_64
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Getting cross sectional forecasts for scalar calculation for ewmac16_64 over CORN, EUROSTX, MXP, SOFR, US10, V2X
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac16_64
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac16_64
# 2025-03-31 19:17:19 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac16_64
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac16_64
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac16_64
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac32_128
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac32_128
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Getting cross sectional forecasts for scalar calculation for ewmac32_128 over CORN, EUROSTX, MXP, SOFR, US10, V2X
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac32_128
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac32_128
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac32_128
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac32_128
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac32_128
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac64_256
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac64_256
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Getting cross sectional forecasts for scalar calculation for ewmac64_256 over CORN, EUROSTX, MXP, SOFR, US10, V2X
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac64_256
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac64_256
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac64_256
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac64_256
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac64_256
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating forecast weights for CORN
# 2025-03-31 19:17:20 INFO base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating raw forecast weights for CORN
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX carry
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP carry
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR carry
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 carry
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X carry
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:20 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac16_64
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac16_64
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac16_64
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac16_64
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac16_64
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac32_128
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac32_128
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac32_128
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac32_128
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac32_128
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac64_256
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac64_256
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac64_256
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac64_256
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac64_256
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for SOFR
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating pandl for instrument forecast for CORN carry
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Getting vol target
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating pandl for instrument forecast for CORN ewmac16_64
# 2025-03-31 19:17:21 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating pandl for instrument forecast for CORN ewmac32_128
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating pandl for instrument forecast for CORN ewmac64_256
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating pandl for instrument forecast for EUROSTX carry
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating pandl for instrument forecast for EUROSTX ewmac16_64
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating pandl for instrument forecast for EUROSTX ewmac32_128
# 2025-03-31 19:17:22 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating pandl for instrument forecast for EUROSTX ewmac64_256
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument forecast for MXP carry
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument forecast for MXP ewmac16_64
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument forecast for MXP ewmac32_128
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument forecast for MXP ewmac64_256
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating pandl for instrument forecast for SOFR carry
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating pandl for instrument forecast for SOFR ewmac16_64
# 2025-03-31 19:17:23 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating pandl for instrument forecast for SOFR ewmac32_128
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating pandl for instrument forecast for SOFR ewmac64_256
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating pandl for instrument forecast for US10 carry
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating pandl for instrument forecast for US10 ewmac16_64
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating pandl for instrument forecast for US10 ewmac32_128
# 2025-03-31 19:17:24 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating pandl for instrument forecast for US10 ewmac64_256
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating pandl for instrument forecast for V2X carry
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating pandl for instrument forecast for V2X ewmac16_64
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating pandl for instrument forecast for V2X ewmac32_128
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating pandl for instrument forecast for V2X ewmac64_256
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Using pooled gross returns
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Using pooled turnover cost SR for CORN
# 2025-03-31 19:17:25 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/0.7/0.7 secs left/elapsed/total)
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2025-03-31 19:17:26 INFO base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating forecast div multiplier for CORN
# 2025-03-31 19:17:26 INFO base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating forecast correlations over CORN, EUROSTX, MXP, SOFR, US10, V2X
#  [================================================================================] 100.0% Estimating correlations (0.0/0.1/0.1 secs left/elapsed/total)
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} No mapping applied for CORN
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating subsystem position for EUROSTX
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating volatility scalar for EUROSTX
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating instrument value vol for EUROSTX
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating instrument currency vol for EUROSTX
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating combined forecast for EUROSTX
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating forecast weights for EUROSTX
# 2025-03-31 19:17:26 INFO base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating raw forecast weights for EUROSTX
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Using pooled gross returns
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Using pooled turnover cost SR for EUROSTX
# 2025-03-31 19:17:26 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/0.7/0.7 secs left/elapsed/total)
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2025-03-31 19:17:27 INFO base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating forecast div multiplier for EUROSTX
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} No mapping applied for EUROSTX
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating subsystem position for MXP
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating volatility scalar for MXP
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating instrument value vol for MXP
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating instrument currency vol for MXP
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating combined forecast for MXP
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating forecast weights for MXP
# 2025-03-31 19:17:27 INFO base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating raw forecast weights for MXP
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Using pooled gross returns
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Using pooled turnover cost SR for MXP
# 2025-03-31 19:17:27 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/0.7/0.7 secs left/elapsed/total)
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2025-03-31 19:17:28 INFO base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating forecast div multiplier for MXP
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} No mapping applied for MXP
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating subsystem position for SOFR
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating volatility scalar for SOFR
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating instrument value vol for SOFR
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating instrument currency vol for SOFR
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating combined forecast for SOFR
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating forecast weights for SOFR
# 2025-03-31 19:17:28 INFO base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating raw forecast weights for SOFR
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Using pooled gross returns
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Using pooled turnover cost SR for SOFR
# 2025-03-31 19:17:28 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/0.7/0.7 secs left/elapsed/total)
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for SOFR
# 2025-03-31 19:17:29 INFO base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating forecast div multiplier for SOFR
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} No mapping applied for SOFR
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating subsystem position for US10
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating volatility scalar for US10
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating instrument value vol for US10
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating instrument currency vol for US10
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating combined forecast for US10
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating forecast weights for US10
# 2025-03-31 19:17:29 INFO base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating raw forecast weights for US10
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Using pooled gross returns
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Using pooled turnover cost SR for US10
# 2025-03-31 19:17:29 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/0.7/0.7 secs left/elapsed/total)
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2025-03-31 19:17:30 INFO base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating forecast div multiplier for US10
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} No mapping applied for US10
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating subsystem position for V2X
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating volatility scalar for V2X
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating instrument value vol for V2X
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating instrument currency vol for V2X
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating combined forecast for V2X
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating forecast weights for V2X
# 2025-03-31 19:17:30 INFO base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating raw forecast weights for V2X
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Using pooled gross returns
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Using pooled turnover cost SR for V2X
# 2025-03-31 19:17:30 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/0.7/0.7 secs left/elapsed/total)
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2025-03-31 19:17:31 INFO base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating forecast div multiplier for V2X
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} No mapping applied for V2X
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Following instruments will have zero weight in optimisation of instrument weights as they have no positions (possibly too expensive?) []
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating pandl for subsystem for instrument CORN
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating buffers for CORN
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating forecast method buffers for CORN
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating buffered subsystem positions
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating pandl for subsystem for instrument EUROSTX
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating buffers for EUROSTX
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating forecast method buffers for EUROSTX
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating buffered subsystem positions
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for subsystem for instrument MXP
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating buffers for MXP
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating forecast method buffers for MXP
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating buffered subsystem positions
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating pandl for subsystem for instrument SOFR
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating buffers for SOFR
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating forecast method buffers for SOFR
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating buffered subsystem positions
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating pandl for subsystem for instrument US10
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating buffers for US10
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating forecast method buffers for US10
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating buffered subsystem positions
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating pandl for subsystem for instrument V2X
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating buffers for V2X
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating forecast method buffers for V2X
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating buffered subsystem positions
# 2025-03-31 19:17:31 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:32 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating raw instrument weights
# 2025-03-31 19:17:32 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Using only returns of asset for gross returns
# 2025-03-31 19:17:32 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Using unpooled cost SR for asset
#  [================================================================================] 100.0% Optimising weights (0.0/0.1/0.1 secs left/elapsed/total)
# 2025-03-31 19:17:32 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Following instruments will have zero weight in optimisation of instrument weights as they have no positions (possibly too expensive?) []
# 2025-03-31 19:17:33 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating instrument div. multiplier
# 2025-03-31 19:17:33 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating instrument correlations
#  [================================================================================] 100.0% Estimating correlations (0.0/0.0/0.0 secs left/elapsed/total)
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} No risk overlay in config: won't apply risk scaling
# index
# 1972-10-18         NaN
# 1972-10-19         NaN
# 1972-10-20         NaN
# 1972-10-23         NaN
# 1972-10-24         NaN
#                 ...
# 2024-03-22   -7.167150
# 2024-03-25   -7.187770
# 2024-03-26   -6.676278
# 2024-03-27   -6.625330
# 2024-03-28   -4.549236
# Freq: B, Length: 13422, dtype: float64

# %% [markdown]
# ### 如何查看回测的中间结果

# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system()
#system.rules.get_raw_forecast("CORN", "ewmac64_256")

#system.rules.get_raw_forecast("CORN", "carry")

system.accounts.portfolio().stats()
system.accounts.portfolio().curve().plot()
system.accounts.portfolio().percent.curve().plot()
system.accounts.pandl_for_instrument("MXP").percent.stats()
system.accounts.pandl_for_instrument_forecast("MXP", "carry").sharpe()
# Out:
# 2025-03-31 19:17:33 DEBUG config {'type': 'config', 'stage': 'config'} Adding config defaults
# 2025-03-31 19:17:33 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-03-31 19:17:33 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-03-31 19:17:33 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-03-31 19:17:33 INFO base_system {'stage': 'accounts'} Calculating pandl for portfolio
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'positionSize'} Getting vol target
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating pandl for instrument for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating notional position for CORN
# 2025-03-31 19:17:33 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating instrument weights
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating raw instrument weights
# 2025-03-31 19:17:33 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-03-31 19:17:33 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-03-31 19:17:33 DEBUG base_system Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2025-03-31 19:17:33 DEBUG base_system Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2025-03-31 19:17:33 DEBUG base_system Following instruments marked as not trading []
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating subsystem position for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating volatility scalar for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating instrument value vol for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'CORN'} Calculating instrument currency vol for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily volatility for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating combined forecast for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN carry
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for carry
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac16_64
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac16_64
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac32_128
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac32_128
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'CORN'} Calculating capped forecast for CORN ewmac64_256
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rules', 'instrument_code': 'CORN'} Calculating raw forecast CORN for ewmac64_256
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Calculating forecast weights for CORN
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX carry
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for carry
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily volatility for EUROSTX
# 2025-03-31 19:17:33 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily volatility for MXP
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily volatility for SOFR
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily volatility for US10
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for carry
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily volatility for V2X
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac16_64
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac16_64
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac16_64
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac16_64
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac16_64
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac16_64
# 2025-03-31 19:17:34 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac16_64
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac16_64
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac16_64
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac16_64
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac32_128
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX'} Calculating capped forecast for EUROSTX ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'EUROSTX'} Calculating raw forecast EUROSTX for ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'MXP'} Calculating capped forecast for MXP ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'MXP'} Calculating raw forecast MXP for ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'SOFR'} Calculating capped forecast for SOFR ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'SOFR'} Calculating raw forecast SOFR for ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'US10'} Calculating capped forecast for US10 ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'US10'} Calculating raw forecast US10 for ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'forecastScaleCap', 'instrument_code': 'V2X'} Calculating capped forecast for V2X ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rules', 'instrument_code': 'V2X'} Calculating raw forecast V2X for ewmac64_256
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Non-nested dict of forecast weights for CORN {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} Using fixed FDM multiplier of 1.310 for CORN
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'CORN'} No mapping applied for CORN
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating subsystem position for EUROSTX
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating volatility scalar for EUROSTX
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating instrument value vol for EUROSTX
# 2025-03-31 19:17:35 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'EUROSTX'} Calculating instrument currency vol for EUROSTX
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating combined forecast for EUROSTX
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Calculating forecast weights for EUROSTX
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Non-nested dict of forecast weights for EUROSTX {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} Using fixed FDM multiplier of 1.310 for EUROSTX
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'EUROSTX'} No mapping applied for EUROSTX
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating subsystem position for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating volatility scalar for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating instrument value vol for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'MXP'} Calculating instrument currency vol for MXP
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating combined forecast for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Calculating forecast weights for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Non-nested dict of forecast weights for MXP {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} Using fixed FDM multiplier of 1.310 for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'MXP'} No mapping applied for MXP
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating subsystem position for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating volatility scalar for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating instrument value vol for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'SOFR'} Calculating instrument currency vol for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating combined forecast for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Calculating forecast weights for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Non-nested dict of forecast weights for SOFR {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} Using fixed FDM multiplier of 1.310 for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'SOFR'} No mapping applied for SOFR
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating subsystem position for US10
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating volatility scalar for US10
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating instrument value vol for US10
# 2025-03-31 19:17:36 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'US10'} Calculating instrument currency vol for US10
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating combined forecast for US10
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Calculating forecast weights for US10
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Non-nested dict of forecast weights for US10 {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} Using fixed FDM multiplier of 1.310 for US10
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'US10'} No mapping applied for US10
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating subsystem position for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating volatility scalar for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating instrument value vol for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'positionSize', 'instrument_code': 'V2X'} Calculating instrument currency vol for V2X
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating combined forecast for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Calculating forecast weights for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Non-nested dict of forecast weights for V2X {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} Using fixed FDM multiplier of 1.310 for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'combForecast', 'instrument_code': 'V2X'} No mapping applied for V2X
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Following instruments will have zero weight in optimisation of instrument weights as they have no positions (possibly too expensive?) []
# 2025-03-31 19:17:37 INFO base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Using fixed diversification multiplier 1.890000
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} No risk overlay in config: won't apply risk scaling
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating buffers for CORN
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'CORN'} Calculating forecast method buffers for CORN
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating buffered positions
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'CORN'} Calculating pandl for instrument for CORN
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'CORN'} Calculating daily prices for CORN
# /Users/henrik/dev/pysystemtrade/syscore/pandas/frequency.py:225: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly_index = list(df.resample("1M").last().index)  ## last day in month
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating pandl for instrument for EUROSTX
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'EUROSTX'} Calculating notional position for EUROSTX
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'EUROSTX'} No risk overlay in config: won't apply risk scaling
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'EUROSTX'} Calculating buffers for EUROSTX
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'EUROSTX'} Calculating forecast method buffers for EUROSTX
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating buffered positions
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'EUROSTX'} Calculating pandl for instrument for EUROSTX
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'EUROSTX'} Calculating daily prices for EUROSTX
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument for MXP
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'MXP'} Calculating notional position for MXP
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'MXP'} No risk overlay in config: won't apply risk scaling
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'MXP'} Calculating buffers for MXP
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'MXP'} Calculating forecast method buffers for MXP
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating buffered positions
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument for MXP
# 2025-03-31 19:17:37 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating pandl for instrument for SOFR
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'SOFR'} Calculating notional position for SOFR
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'SOFR'} No risk overlay in config: won't apply risk scaling
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'SOFR'} Calculating buffers for SOFR
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'SOFR'} Calculating forecast method buffers for SOFR
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating buffered positions
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'SOFR'} Calculating pandl for instrument for SOFR
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'SOFR'} Calculating daily prices for SOFR
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating pandl for instrument for US10
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'US10'} Calculating notional position for US10
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'US10'} No risk overlay in config: won't apply risk scaling
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'US10'} Calculating buffers for US10
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'US10'} Calculating forecast method buffers for US10
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating buffered positions
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'US10'} Calculating pandl for instrument for US10
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'US10'} Calculating daily prices for US10
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating pandl for instrument for V2X
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'V2X'} Calculating notional position for V2X
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'V2X'} No risk overlay in config: won't apply risk scaling
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'V2X'} Calculating buffers for V2X
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'V2X'} Calculating forecast method buffers for V2X
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating buffered positions
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'V2X'} Calculating pandl for instrument for V2X
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'V2X'} Calculating daily prices for V2X
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument for MXP
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument for MXP
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'MXP'} Calculating pandl for instrument forecast for MXP carry
# 2025-03-31 19:17:38 DEBUG base_system {'stage': 'rawdata', 'instrument_code': 'MXP'} Calculating daily prices for MXP
# np.float64(0.4409062306935505)
